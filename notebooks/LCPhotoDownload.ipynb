# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IGES-Geospatial/globe-observer-utils/blob/main/notebooks/LCPhotoDownload.ipynb)

# %% [markdown]
# # Import go_utils
#
# This cell should only be run for Google Colab Notebooks or if go_utils is not installed on your local computer. Note that Google Colab Users will have to restart the environment after this is run. However, running this particular notebook on Google Collab is not recommended.

# %%
# !pip install go_utils

# %% [markdown]
# # Get Land Cover Data
#
# This collects data from January 1st, 2021 to January 2nd, 2021.

# %%
from go_utils import get_api_data

lc_df = get_api_data("land_covers", start_date="2021-01-01", end_date="2021-01-02")

# %%
lc_df
# Out:
#    lc_measuredDate       lc_updateDate      lc_publishDate  lc_organizationId  \
# 0       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           17043304
# 1       2021-01-02 2021-06-18 15:17:16 2021-06-18 15:20:00           61563928
# 2       2021-01-02 2021-06-18 15:17:16 2021-06-18 15:20:00           61563928
# 3       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           16191201
# 4       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           16191201
# 5       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           16191201
# 6       2021-01-02 2021-05-23 17:40:12 2021-06-17 21:00:43           16191201
# 7       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           16191201
# 8       2021-01-01 2021-05-23 17:40:12 2021-06-17 21:00:43           17179766
# 9       2021-01-02 2021-05-23 17:40:12 2021-06-17 21:00:43           60780881
# 10      2021-01-02 2021-05-23 17:40:12 2021-06-17 21:00:43           60780881
# ...

# %% [markdown]
# # Download Photos
#
# By specifying `up_photo` and `down_photo` as blank, only the North, East, South, and West photos will be downloaded.

# %%
from go_utils.photo_download import download_lc_photos

download_lc_photos(lc_df, "LC_Photos", up_photo="", down_photo="")
# Out:
# {('https://data.globe.gov/system/photos/2021/01/01/2071634/original.jpg',
#   'LC_Photos',
#   'lc-North-2021-01-01-38504-2071634.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071635/original.jpg',
#   'LC_Photos',
#   'lc-East-2021-01-01-38504-2071635.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071636/original.jpg',
#   'LC_Photos',
#   'lc-South-2021-01-01-38504-2071636.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071637/original.jpg',
#   'LC_Photos',
#   'lc-West-2021-01-01-38504-2071637.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071775/original.jpg',
#   'LC_Photos',
#   'lc-North-2021-01-01-38505-2071775.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071776/original.jpg',
#   'LC_Photos',
#   'lc-East-2021-01-01-38505-2071776.png'),
#  ('https://data.globe.gov/system/photos/2021/01/01/2071777/original.jpg',
#   'LC_Photos',
#   'lc-South-2021-01-01-38505-2071777.png'),
# ...
